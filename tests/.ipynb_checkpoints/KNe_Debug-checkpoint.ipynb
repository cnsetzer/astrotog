# %%
from astrotog import transient_obs_dist as tod
import numpy as np
from math import inf
from astropy.cosmology import Planck15 as cosmo
import sncosmo
surveydb_path = '/Users/cnsetzer/Documents/LSST/surveydbs/minion_1016_sqlite.db'
fields = ['fieldID', 'fieldRA', 'fieldDec', 'filter', 'expMJD', 'fiveSigmaDepth']
param_priors = {'zmin': 0.0, 'zmax': 0.1, 'cosmology': cosmo,
                'kappa_min': 1, 'kappa_max': 10, 'm_ej_min': 0.01,
                'm_ej_max': 0.2, 'v_ej_min': 0.01, 'v_ej_max': 0.5}
instrument_params = {'FOV_rad': np.deg2rad(1.75), 'Mag_Sys': 'ab'}
Cuts = {'SNR': {'upper': inf, 'lower': 5}}
gen_flag = 'cycle'
db_flag = 'wfd'
z0 = 0.00000225975
z1 = 1

# %%
sedsdb_path = "../sedb/rosswog/NSNS/winds"

# %%
sed_db = tod.Get_SEDdb(sedsdb_path)

# %%
sed_db.keys()
# Out:
# dict_keys(['SED_wind16', 'SED_wind17', 'SED_wind15', 'SED_wind14', 'SED_wind10', 'SED_wind12_kappa10', 'SED_wind11', 'SED_wind13', 'SED_wind12', 'SED_wind2', 'SED_wind3', 'SED_wind1', 'SED_wind11_kappa10', 'SED_wind4', 'SED_wind5', 'SED_wind7', 'SED_wind6', 'SED_wind8', 'SED_wind9', 'SED_wind20', 'SED_wind21', 'SED_wind19', 'SED_wind18'])

# %%
test_sed = {}
test_key = 'SED_wind16'
test_model = sed_db[test_key]['model']
test_sed[test_key] = sed_db[test_key]

# %%
sncosmo.plot_lc(model = test_sed[test_key]['model'], bands = ['lsstg', 'lsstr', 'lssti', 'lsstz'])

# %%
sed_db[test_key]['parameters'].keys()
# Out:
# dict_keys(['kappa', 'm_ej', 'v_ej'])

# %%
test_model.flux(0.5,1500)
# Out:
# 0.00046918600000000002

# %%
test_model.bandmag('lsstr','ab',2.5)
# Out:
# -13.345317371575582

# %%
test_sed[test_key]['parameters']
# Out:
# {'kappa': 1.0, 'm_ej': 0.2, 'v_ej': 0.05}

# %%
test_sed = tod.Set_SED_Redshift(test_sed, [z1],cosmo)

# %%
sncosmo.plot_lc(model = test_sed[test_key]['model'], bands = ['lsstg', 'lsstr', 'lssti', 'lsstz'])

# %%
test_model.bandmag('lsstr','ab',2.5)
